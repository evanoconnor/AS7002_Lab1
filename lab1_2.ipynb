# %%
import numpy as np
import matplotlib.pylab as plt

# %%
c = 29979245800.
G = 6.6743e-8
K = 0.00126
Gamma = 2.54

# %%
#equation of state, P(\rho)
def pressure_from_rho(rho):
    press = 
    
    return press

#need to have the EOS inverted, since we solve for P, then need to know the \rho
def rho_from_pressure(pressure):
    rho = 
    
    return rho

#need and expression for the internal energy excluding rest mass
def epsilon_from_rho(rho):
    epsilon = 
    
    return epsilon

#our TOV equations are writen in terms of the energy density, which is the rest mass plus the internal.
def rhoR_from_rho(rho):
    rhoR = 
    
    return rhoR

#The TOV equation for pressure
def dPdr(rhoR,mass,pressure,radius):
    if radius==0.0: 
        dPdr = 
    else:    
        dPdr = 
    
    return dPdr
    
#The TOV equation for mass
def dmdr(rhoR,radius):
    dmdr = 
    
    return dmdr

#our Runge-Kutta solver for neutron stars
def solve_tov(centralrho=1e15,nzones=400,deltar=5000.):
    rho0 = centralrho
    P0 = pressure_from_rho(rho0)
    
    pressure = np.zeros(nzones)
    rho = np.zeros(nzones)
    mass = np.zeros(nzones)
    radius = np.zeros(nzones)

    #initial conditions
    pressure[0] = P0
    rho[0] = rho0
    radius[0] = 0.0
    mass[0] = 0.0

    endi = nzones
    for i in range(1,nzones):
        #at this point, you have pressure, rho, radius, 
        #and mass for the i-1 zone, you need to solve 
        #the TOV differential equations to find out the
        #pressure, rho, radius, and mass for zone i
        
        
        
        #end condition
        if :
            #flag this i as invalid because pressure is negative
            endi = i
            break
        
    #return valid data from i=0 to endi-1, i.e. quantity[:endi]
    return radius[:endi],mass[:endi],rho[:endi]
